# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import seaborn as sns
from scipy import stats


Immo2= pd.read_json(r"C:\Users\admin\Documents\becode_projects\Immo_Data Analisis\final_dataset_T.json")
print(Immo2.head(10))

Immo2.to_csv("ImmoD.csv")
# Out:
#                                                   Url  BathroomCount  \
# 2   https://www.immoweb.be/en/classified/apartment...            1.0
# 6   https://www.immoweb.be/en/classified/house/for...            6.0
# 8   https://www.immoweb.be/en/classified/house/for...            2.0
# 10  https://www.immoweb.be/en/classified/house/for...            1.0
# 11  https://www.immoweb.be/en/classified/apartment...            0.0
# 14  https://www.immoweb.be/en/classified/apartment...            1.0
# 15  https://www.immoweb.be/en/classified/house/for...            4.0
# 18  https://www.immoweb.be/en/classified/house/for...            0.0
# 22  https://www.immoweb.be/en/classified/apartment...            2.0
# 23  https://www.immoweb.be/en/classified/apartment...            NaN
#
#     BedroomCount  ConstructionYear  Country         District  Fireplace  \
# 2              1            1969.0  Belgium           Brugge        NaN
# 6             13            1920.0  Belgium          Tournai        NaN
# 8              4            2008.0  Belgium           Brugge        NaN
# 10             4               NaN  Belgium           Veurne        NaN
# 11             2            1972.0  Belgium          Hasselt        NaN
# 14             1            1994.0  Belgium         Brussels        NaN
# 15             6            1970.0  Belgium         Nivelles        1.0
# 18             2               NaN  Belgium         Mechelen        NaN
# 22             3            2023.0  Belgium  Halle-Vilvoorde        NaN
# 23             2               NaN  Belgium     Sint-Niklaas        NaN
#
#       FloodingZone  Furnished  Garden  ...  RoomCount ShowerCount  \
# 2             None        NaN     NaN  ...        1.0         0.0
# 6             None        0.0     NaN  ...       31.0         NaN
# 8   NON_FLOOD_ZONE        1.0     NaN  ...        NaN         0.0
# 10            None        NaN     1.0  ...        NaN         NaN
# 11  NON_FLOOD_ZONE        NaN     NaN  ...        1.0         0.0
# 14            None        1.0     NaN  ...        NaN         NaN
# 15  NON_FLOOD_ZONE        NaN     1.0  ...        NaN         0.0
# 18  NON_FLOOD_ZONE        NaN     NaN  ...        1.0         0.0
# 22            None        NaN     NaN  ...        NaN         0.0
# 23            None        NaN     NaN  ...        NaN         0.0
#
#     StateOfBuilding SubtypeOfProperty  SurfaceOfPlot  SwimmingPool Terrace  \
# 2              GOOD       flat_studio            NaN           NaN     1.0
# 6              GOOD   apartment_block          130.0           NaN     NaN
# 8              GOOD             house            0.0           NaN     NaN
# 10    TO_BE_DONE_UP             house          170.0           0.0     1.0
# 11           AS_NEW         apartment            NaN           NaN     1.0
# 14           AS_NEW         apartment            NaN           0.0     1.0
# 15             GOOD             villa         2519.0           NaN     1.0
# 18             None             house          423.0           NaN     NaN
# 22             None         apartment            NaN           0.0     NaN
# 23             None         apartment            NaN           NaN     NaN
#
#     ToiletCount  TypeOfProperty                TypeOfSale
# 2           1.0               2          residential_sale
# 6           5.0               1          residential_sale
# 8           2.0               1          residential_sale
# 10          2.0               1          residential_sale
# 11          1.0               2          residential_sale
# 14          1.0               2          residential_sale
# 15          5.0               1  residential_monthly_rent
# 18          0.0               1          residential_sale
# 22          NaN               2          residential_sale
# 23          NaN               2          residential_sale
#
# [10 rows x 32 columns]

# %%
immo_Dennis = pd.read_csv("ImmoD.csv")
#print(immo_Dennis.head)
print(immo_Dennis.columns.tolist())

#print(immo_Dennis.head())
print(immo_Dennis.info())
# Out:
# ['Unnamed: 0', 'Url', 'BathroomCount', 'BedroomCount', 'ConstructionYear', 'Country', 'District', 'Fireplace', 'FloodingZone', 'Furnished', 'Garden', 'GardenArea', 'Kitchen', 'LivingArea', 'Locality', 'MonthlyCharges', 'NumberOfFacades', 'PEB', 'PostalCode', 'Price', 'PropertyId', 'Province', 'Region', 'RoomCount', 'ShowerCount', 'StateOfBuilding', 'SubtypeOfProperty', 'SurfaceOfPlot', 'SwimmingPool', 'Terrace', 'ToiletCount', 'TypeOfProperty', 'TypeOfSale']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118714 entries, 0 to 118713
# Data columns (total 33 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         118714 non-null  int64
#  1   Url                118714 non-null  object
#  2   BathroomCount      109112 non-null  float64
#  3   BedroomCount       118714 non-null  int64
#  4   ConstructionYear   68898 non-null   float64
#  5   Country            118714 non-null  object
#  6   District           118707 non-null  object
#  7   Fireplace          4123 non-null    float64
#  8   FloodingZone       58342 non-null   object
#  9   Furnished          30325 non-null   float64
#  10  Garden             22503 non-null   float64
#  11  GardenArea         22503 non-null   float64
#  12  Kitchen            67134 non-null   object
#  13  LivingArea         104539 non-null  float64
#  14  Locality           118709 non-null  object
#  15  MonthlyCharges     13650 non-null   float64
#  16  NumberOfFacades    76942 non-null   float64
#  17  PEB                85074 non-null   object
#  18  PostalCode         118714 non-null  int64
#  19  Price              118714 non-null  int64
#  20  PropertyId         118714 non-null  int64
#  21  Province           118707 non-null  object
#  22  Region             118707 non-null  object
#  23  RoomCount          32916 non-null   float64
#  24  ShowerCount        57127 non-null   float64
#  25  StateOfBuilding    81622 non-null   object
#  26  SubtypeOfProperty  118714 non-null  object
#  27  SurfaceOfPlot      58237 non-null   float64
#  28  SwimmingPool       40358 non-null   float64
#  29  Terrace            68344 non-null   float64
#  30  ToiletCount        96441 non-null   float64
#  31  TypeOfProperty     118714 non-null  int64
#  32  TypeOfSale         118714 non-null  object
# dtypes: float64(15), int64(6), object(12)
# memory usage: 29.9+ MB
# None

# %%
immo_Dennis.describe()
# Out:
#           Unnamed: 0  BathroomCount   BedroomCount  ConstructionYear  \
# count  118714.000000  109112.000000  118714.000000      68898.000000
# mean    81529.671345       1.232898       2.708383       1987.345496
# std     44347.708008       1.092045       1.855343         47.311922
# min         2.000000       0.000000       0.000000       1753.000000
# 25%     45964.250000       1.000000       2.000000       1964.000000
# 50%     79765.500000       1.000000       3.000000       2000.000000
# 75%    115702.750000       1.000000       3.000000       2023.000000
# max    181792.000000     145.000000     200.000000       8071.000000
#
#        Fireplace     Furnished   Garden    GardenArea     LivingArea  \
# count     4123.0  30325.000000  22503.0  2.250300e+04  104539.000000
# mean         1.0      0.070041      1.0  4.509960e+04     167.396417
# std          0.0      0.255221      0.0  6.666220e+06    1814.592952
# min          1.0      0.000000      1.0  1.000000e+00       9.000000
# 25%          1.0      0.000000      1.0  4.800000e+01      90.000000
# 50%          1.0      0.000000      1.0  1.400000e+02     124.000000
# 75%          1.0      0.000000      1.0  4.500000e+02     182.000000
# max          1.0      1.000000      1.0  1.000000e+09  452230.000000
#
#        MonthlyCharges  ...     PostalCode         Price    PropertyId  \
# count    13650.000000  ...  118714.000000  1.187140e+05  1.187140e+05
# mean        84.239853  ...    5166.113129  3.815797e+05  1.245875e+07
# std        179.608171  ...    3060.657713  4.754330e+05  3.131297e+06
# min          0.000000  ...       0.000000  1.000000e+00  1.882546e+06
# 25%          0.000000  ...    2250.000000  2.000000e+05  1.114592e+07
# 50%         30.000000  ...    4671.000000  3.095000e+05  1.138077e+07
# 75%        120.000000  ...    8400.000000  4.390000e+05  1.146776e+07
# max       5250.000000  ...    9992.000000  3.500000e+07  2.002586e+07
#
#           RoomCount   ShowerCount  SurfaceOfPlot  SwimmingPool  Terrace  \
# count  32916.000000  57127.000000   5.823700e+04  40358.000000  68344.0
# mean       6.806538      0.696186   3.118253e+03      0.050994      1.0
# std        5.458941      6.563612   4.776406e+05      0.219987      0.0
# min        1.000000      0.000000   0.000000e+00      0.000000      1.0
# 25%        2.000000      0.000000   1.480000e+02      0.000000      1.0
# 50%        6.000000      0.000000   3.530000e+02      0.000000      1.0
# 75%       10.000000      1.000000   8.000000e+02      0.000000      1.0
# max       68.000000   1120.000000   1.152500e+08      1.000000      1.0
#
#         ToiletCount  TypeOfProperty
# count  9.644100e+04   118714.000000
# mean   4.120696e+01        1.509460
# std    1.234059e+04        0.499913
# min    0.000000e+00        1.000000
# 25%    1.000000e+00        1.000000
# 50%    1.000000e+00        2.000000
# 75%    2.000000e+00        2.000000
# max    3.832365e+06        2.000000
#
# [8 rows x 21 columns]

# %%
immo_Dennis.duplicated().value_counts()
# Out:
# False    118714
# Name: count, dtype: int64

# %%
#remove duplicates

immo_Dennis_unique= immo_Dennis.drop_duplicates(subset= "Url")

#print(immo_Dennis_unique.info())

bathroom= immo_Dennis_unique[immo_Dennis_unique["BedroomCount"]>5].head()

# %%
Bathroom = immo_Dennis_unique[immo_Dennis_unique["BathroomCount"]>15]
Bathroom["Url"].tolist()
# Out:
# ['https://www.immoweb.be/en/classified/house/for-sale/bastogne/6600/10940526',
#  'https://www.immoweb.be/en/classified/house/for-sale/fauvillers/6637/10940525',
#  'https://www.immoweb.be/en/classified/apartment/for-sale/zandhoven/2240/10890954',
#  'https://www.immoweb.be/en/classified/apartment/for-sale/uccle/1180/10671577',
#  'https://www.immoweb.be/en/classified/house/for-sale/haaltert-denderhoutem/9450/11490286',
#  'https://www.immoweb.be/en/classified/house/for-sale/nandrin/4550/11488639',
#  'https://www.immoweb.be/en/classified/house/for-sale/manage/7170/20006978',
#  'https://www.immoweb.be/en/classified/apartment/for-sale/chatelet/6200/20009193',
#  'https://www.immoweb.be/en/classified/house/for-sale/anderlecht/1070/11388325',
#  'https://www.immoweb.be/en/classified/house/for-sale/huy/4500/11430933',
#  'https://www.immoweb.be/en/classified/house/for-sale/antwerpen/2060/11378341',
#  'https://www.immoweb.be/en/classified/house/for-sale/mechelen/2800/11424400',
#  'https://www.immoweb.be/en/classified/house/for-sale/ciney/5590/11342535',
#  'https://www.immoweb.be/en/classified/house/for-sale/barvaux-sur-ourthe/6940/11303391',
#  'https://www.immoweb.be/en/classified/house/for-sale/molenbeek-saint-jean/1080/11210997',
#  'https://www.immoweb.be/en/classified/house/for-sale/bruxelles/1000/11207442',
#  'https://www.immoweb.be/en/classified/house/for-sale/rendeux/6987/11181824',
#  'https://www.immoweb.be/en/classified/house/for-sale/liege/4020/11351688',
#  'https://www.immoweb.be/en/classified/house/for-sale/brussel/1020/11343564',
#  'https://www.immoweb.be/en/classified/house/for-sale/antwerpen/2060/11017063',
#  'https://www.immoweb.be/en/classified/house/for-sale/charleroi/6010/11013620',
#  'https://www.immoweb.be/en/classified/apartment/for-sale/louveigne/4141/10634220',
#  'https://www.immoweb.be/en/classified/apartment/for-sale/sint-niklaas/9100/10610005',
#  'https://www.immoweb.be/en/classified/house/for-sale/manage/7170/10599752',
#  'https://www.immoweb.be/en/classified/house/for-sale/erpe-mere/9420/11128591',
#  'https://www.immoweb.be/en/classified/house/for-sale/bruxelles/1000/11172456',
#  'https://www.immoweb.be/en/classified/house/for-sale/ixelles/1050/11172409',
#  'https://www.immoweb.be/en/classified/house/for-sale/frahan/6830/11162378',
#  'https://www.immoweb.be/en/classified/house/for-sale/bohan/5550/10082307',
#  'https://www.immoweb.be/en/classified/house/for-sale/schilde/2970/10056580',
#  'https://www.immoweb.be/en/classified/house/for-sale/trois-ponts/4980/9307392',
#  'https://www.immoweb.be/en/classified/house/for-sale/marcinelle/6001/10313320']

# %%
Bedroom = immo_Dennis_unique[immo_Dennis_unique["BedroomCount"]>20]
Bedroom["Url"].tolist()
# Out:
# ['https://www.immoweb.be/en/classified/house/for-sale/sohier/6920/10674407',
#  'https://www.immoweb.be/en/classified/house/for-sale/daverdisse/6929/20018567',
#  'https://www.immoweb.be/en/classified/house/for-sale/knesselare/9910/10661999',
#  'https://www.immoweb.be/en/classified/house/for-sale/jette/1090/20017661',
#  'https://www.immoweb.be/en/classified/house/for-sale/jette/1090/20017659',
#  'https://www.immoweb.be/en/classified/apartment/for-sale/tienen/3300/11490869',
#  'https://www.immoweb.be/en/classified/house/for-sale/brussels/1000/11490449',
#  'https://www.immoweb.be/en/classified/house/for-sale/ans/4430/11490403',
#  'https://www.immoweb.be/en/classified/house/for-sale/nandrin/4550/11488639',
#  'https://www.immoweb.be/en/classified/house/for-sale/verviers/4800/11481911',
#  'https://www.immoweb.be/en/classified/house/for-sale/charleroi/6000/11480810',
#  'https://www.immoweb.be/en/classified/apartment/for-sale/zelzate/9060/11458668',
#  'https://www.immoweb.be/en/classified/house/for-sale/ronse/9600/11456300',
#  'https://www.immoweb.be/en/classified/apartment/for-sale/ronse/9600/11456299',
#  'https://www.immoweb.be/en/classified/house/for-sale/manage/7170/20006978',
#  'https://www.immoweb.be/en/classified/house/for-sale/tournai-kain/7540/11477836',
#  'https://www.immoweb.be/en/classified/apartment/for-sale/deurne/2100/20009863',
#  'https://www.immoweb.be/en/classified/house/for-sale/deurne/2100/20009855',
#  'https://www.immoweb.be/en/classified/apartment/for-sale/deurne/2100/20009851',
#  'https://www.immoweb.be/en/classified/house/for-sale/theux/4910/11397491',
#  'https://www.immoweb.be/en/classified/house/for-sale/anderlecht/1070/11388325',
#  'https://www.immoweb.be/en/classified/house/for-sale/binche/7130/11428008',
#  'https://www.immoweb.be/en/classified/house/for-sale/marche-en-famenne/6900/11426483',
#  'https://www.immoweb.be/en/classified/house/for-sale/houtain-saint-simeon/4682/11442547',
#  'https://www.immoweb.be/en/classified/house/for-sale/ciney/5590/11342535',
#  'https://www.immoweb.be/en/classified/house/for-sale/awans/4340/11282788',
#  'https://www.immoweb.be/en/classified/house/for-sale/schaerbeek/1030/11313431',
#  'https://www.immoweb.be/en/classified/house/for-sale/charleroi/6000/11305074',
#  'https://www.immoweb.be/en/classified/house/for-sale/barvaux-sur-ourthe/6940/11303391',
#  'https://www.immoweb.be/en/classified/house/for-sale/daverdisse/6929/11330511',
#  'https://www.immoweb.be/en/classified/house/for-sale/braives/4260/11301592',
#  'https://www.immoweb.be/en/classified/house/for-sale/molenbeek-saint-jean/1080/11210997',
#  'https://www.immoweb.be/en/classified/house/for-sale/bruxelles/1000/11207442',
#  'https://www.immoweb.be/en/classified/house/for-sale/suarlee/5020/11206459',
#  'https://www.immoweb.be/en/classified/house/for-sale/suarlee/5020/11206457',
#  'https://www.immoweb.be/en/classified/house/for-sale/suarlee/5020/11206460',
#  'https://www.immoweb.be/en/classified/house/for-sale/spa/4900/11292981',
#  'https://www.immoweb.be/en/classified/house/for-sale/la-roche-en-ardenne/6980/11288895',
#  'https://www.immoweb.be/en/classified/apartment/for-sale/herstal/4040/11284867',
#  'https://www.immoweb.be/en/classified/house/for-sale/antwerpen/2610/11359959',
#  'https://www.immoweb.be/en/classified/house/for-sale/andenne/5300/11018956',
#  'https://www.immoweb.be/en/classified/house/for-sale/andenne/5300/11018955',
#  'https://www.immoweb.be/en/classified/house/for-sale/charleroi/6010/11013620',
#  'https://www.immoweb.be/en/classified/house/for-sale/ixelles/1050/11005999',
#  'https://www.immoweb.be/en/classified/house/for-sale/vaux-sur-sure/6640/11087056',
#  'https://www.immoweb.be/en/classified/house/for-sale/woluwe-saint-pierre/1150/11073278',
#  'https://www.immoweb.be/en/classified/house/for-sale/theux/4910/10982781',
#  'https://www.immoweb.be/en/classified/house/for-sale/braine-l-alleud/1420/11067627',
#  'https://www.immoweb.be/en/classified/house/for-sale/mons/7000/11066875',
#  'https://www.immoweb.be/en/classified/house/for-sale/richelle/4600/11065178',
#  'https://www.immoweb.be/en/classified/house/for-sale/turnhout/2300/11061632',
#  'https://www.immoweb.be/en/classified/house/for-sale/liege/4000/11046519',
#  'https://www.immoweb.be/en/classified/apartment/for-sale/sint-niklaas/9100/10610005',
#  'https://www.immoweb.be/en/classified/house/for-sale/stambruges/7973/10599569',
#  'https://www.immoweb.be/en/classified/house/for-sale/andenne/5300/11027724',
#  'https://www.immoweb.be/en/classified/house/for-sale/tournai/7500/10567143',
#  'https://www.immoweb.be/en/classified/house/for-sale/erpe-mere/9420/11128591',
#  'https://www.immoweb.be/en/classified/house/for-sale/st-gilles/1060/10529467',
#  'https://www.immoweb.be/en/classified/house/for-sale/oostende/8400/11125495',
#  'https://www.immoweb.be/en/classified/apartment/for-sale/aalter/9910/11096442',
#  'https://www.immoweb.be/en/classified/house/for-sale/liege/4000/11173748',
#  'https://www.immoweb.be/en/classified/house/for-sale/bruxelles/1000/11172456',
#  'https://www.immoweb.be/en/classified/house/for-sale/ixelles/1050/11172409',
#  'https://www.immoweb.be/en/classified/house/for-sale/menen/8930/11170092',
#  'https://www.immoweb.be/en/classified/house/for-sale/anderlecht/1070/11143907',
#  'https://www.immoweb.be/en/classified/house/for-sale/rhisnes/5080/11138904',
#  'https://www.immoweb.be/en/classified/house/for-sale/mariembourg/5660/9954226',
#  'https://www.immoweb.be/en/classified/house/for-sale/theux/4910/9948962',
#  'https://www.immoweb.be/en/classified/house/for-sale/ixelles/1050/9789173',
#  'https://www.immoweb.be/en/classified/house/for-sale/malmedy/4960/9123837',
#  'https://www.immoweb.be/en/classified/house/for-sale/braine-l-alleud/1420/10191507']

# %%
Bedroom = immo_Dennis_unique[immo_Dennis_unique["GardenArea"]>200000]
Bedroom["Url"].tolist()
# Out:
# ['https://www.immoweb.be/en/classified/house/for-sale/soignies/7061/11323443',
#  'https://www.immoweb.be/en/classified/house/for-sale/rendeux/6987/11181824']

# %%
Districts = immo_Dennis_unique["District"].unique()
print(Districts)
# Out:
# ['Brugge' 'Tournai' 'Veurne' 'Hasselt' 'Brussels' 'Nivelles' 'Mechelen'
#  'Halle-Vilvoorde' 'Sint-Niklaas' 'Oostend' 'Antwerp' 'Ieper' 'Mons'
#  'Namur' 'Philippeville' 'Soignies' 'Leuven' 'Charleroi' 'Liège' 'Maaseik'
#  'Verviers' 'Aalst' 'Tongeren' 'Marche-en-Famenne' 'Kortrijk' 'Gent'
#  'Eeklo' 'Diksmuide' 'Dendermonde' 'Waremme' 'Huy' 'Oudenaarde' 'Dinant'
#  'Neufchâteau' 'Mouscron' 'Tielt' 'Roeselare' 'Turnhout' 'Thuin' 'Arlon'
#  'Virton' 'Ath' 'Bastogne' nan]

# %%
#delete Url

del immo_Dennis_unique["Url"]

print(immo_Dennis_unique)
# Out:
#         Unnamed: 0  BathroomCount  BedroomCount  ConstructionYear  Country  \
# 0                2            1.0             1            1969.0  Belgium
# 1                6            6.0            13            1920.0  Belgium
# 2                8            2.0             4            2008.0  Belgium
# 3               10            1.0             4               NaN  Belgium
# 4               11            0.0             2            1972.0  Belgium
# ...            ...            ...           ...               ...      ...
# 118709      181788            1.0             3            2024.0  Belgium
# 118710      181789            4.0             4               NaN  Belgium
# 118711      181790            1.0             2               NaN  Belgium
# 118712      181791            1.0             2               NaN  Belgium
# 118713      181792            2.0             3               NaN  Belgium
#
#         District  Fireplace         FloodingZone  Furnished  Garden  ...  \
# 0         Brugge        NaN                  NaN        NaN     NaN  ...
# 1        Tournai        NaN                  NaN        0.0     NaN  ...
# 2         Brugge        NaN       NON_FLOOD_ZONE        1.0     NaN  ...
# 3         Veurne        NaN                  NaN        NaN     1.0  ...
# 4        Hasselt        NaN       NON_FLOOD_ZONE        NaN     NaN  ...
# ...          ...        ...                  ...        ...     ...  ...
# 118709      Gent        NaN                  NaN        NaN     1.0  ...
# 118710   Antwerp        NaN                  NaN        0.0     NaN  ...
# 118711   Antwerp        NaN       NON_FLOOD_ZONE        NaN     NaN  ...
# 118712    Brugge        NaN  POSSIBLE_FLOOD_ZONE        NaN     NaN  ...
# 118713  Brussels        NaN       NON_FLOOD_ZONE        NaN     NaN  ...
#
#         RoomCount ShowerCount  StateOfBuilding SubtypeOfProperty  \
# 0             1.0         0.0             GOOD       flat_studio
# 1            31.0         NaN             GOOD   apartment_block
# 2             NaN         0.0             GOOD             house
# 3             NaN         NaN    TO_BE_DONE_UP             house
# 4             1.0         0.0           AS_NEW         apartment
# ...           ...         ...              ...               ...
# 118709        4.0         NaN             GOOD             house
# 118710        NaN         NaN   JUST_RENOVATED   apartment_block
# 118711        NaN         NaN             GOOD         apartment
# 118712        8.0         NaN              NaN         apartment
# 118713        NaN         NaN             GOOD         apartment
#
#         SurfaceOfPlot  SwimmingPool Terrace  ToiletCount  TypeOfProperty  \
# 0                 NaN           NaN     1.0          1.0               2
# 1               130.0           NaN     NaN          5.0               1
# 2                 0.0           NaN     NaN          2.0               1
# 3               170.0           0.0     1.0          2.0               1
# 4                 NaN           NaN     1.0          1.0               2
# ...               ...           ...     ...          ...             ...
# 118709          234.0           NaN     NaN          0.0               1
# 118710          202.0           NaN     NaN          NaN               1
# 118711            NaN           0.0     1.0          1.0               2
# 118712            NaN           NaN     1.0          NaN               2
# 118713            NaN           NaN     1.0          3.0               2
#
#                       TypeOfSale
# 0               residential_sale
# 1               residential_sale
# 2               residential_sale
# 3               residential_sale
# 4               residential_sale
# ...                          ...
# 118709          residential_sale
# 118710          residential_sale
# 118711          residential_sale
# 118712          residential_sale
# 118713  residential_monthly_rent
#
# [118714 rows x 32 columns]

# %%
blank=immo_Dennis_unique.isnull().sum()
type_n = immo_Dennis_unique.dtypes
print(blank, type_n)
# Out:
# Unnamed: 0                0
# BathroomCount          9602
# BedroomCount              0
# ConstructionYear      49816
# Country                   0
# District                  7
# Fireplace            114591
# FloodingZone          60372
# Furnished             88389
# Garden                96211
# GardenArea            96211
# Kitchen               51580
# LivingArea            14175
# Locality                  5
# MonthlyCharges       105064
# NumberOfFacades       41772
# PEB                   33640
# PostalCode                0
# Price                     0
# PropertyId                0
# Province                  7
# Region                    7
# RoomCount             85798
# ShowerCount           61587
# StateOfBuilding       37092
# SubtypeOfProperty         0
# SurfaceOfPlot         60477
# SwimmingPool          78356
# Terrace               50370
# ToiletCount           22273
# TypeOfProperty            0
# TypeOfSale                0
# dtype: int64 Unnamed: 0             int64
# BathroomCount        float64
# BedroomCount           int64
# ConstructionYear     float64
# Country               object
# District              object
# Fireplace            float64
# FloodingZone          object
# Furnished            float64
# Garden               float64
# GardenArea           float64
# Kitchen               object
# LivingArea           float64
# Locality              object
# MonthlyCharges       float64
# NumberOfFacades      float64
# PEB                   object
# PostalCode             int64
# Price                  int64
# PropertyId             int64
# Province              object
# Region                object
# RoomCount            float64
# ShowerCount          float64
# StateOfBuilding       object
# SubtypeOfProperty     object
# SurfaceOfPlot        float64
# SwimmingPool         float64
# Terrace              float64
# ToiletCount          float64
# TypeOfProperty         int64
# TypeOfSale            object
# dtype: object

# %%
Type = immo_Dennis_unique[["TypeOfProperty"]]
print(Type)
# Out:
#         TypeOfProperty
# 0                    2
# 1                    1
# 2                    1
# 3                    1
# 4                    2
# ...                ...
# 118709               1
# 118710               1
# 118711               2
# 118712               2
# 118713               2
#
# [118714 rows x 1 columns]

# %%
ofs_immoD = immo_Dennis_unique.drop(immo_Dennis_unique[immo_Dennis["TypeOfProperty"] == 2].index)


print(ofs_immoD.head(10))
# Out:
#     Unnamed: 0  BathroomCount  BedroomCount  ConstructionYear  Country  \
# 1            6            6.0            13            1920.0  Belgium
# 2            8            2.0             4            2008.0  Belgium
# 3           10            1.0             4               NaN  Belgium
# 6           15            4.0             6            1970.0  Belgium
# 7           18            0.0             2               NaN  Belgium
# 12          27            3.0             5            1987.0  Belgium
# 15          33            1.0             8            1923.0  Belgium
# 16          34            1.0             3               NaN  Belgium
# 19          37            0.0             1            1860.0  Belgium
# 20          38            2.0             0            1950.0  Belgium
#
#          District  Fireplace    FloodingZone  Furnished  Garden  ...  \
# 1         Tournai        NaN             NaN        0.0     NaN  ...
# 2          Brugge        NaN  NON_FLOOD_ZONE        1.0     NaN  ...
# 3          Veurne        NaN             NaN        NaN     1.0  ...
# 6        Nivelles        1.0  NON_FLOOD_ZONE        NaN     1.0  ...
# 7        Mechelen        NaN  NON_FLOOD_ZONE        NaN     NaN  ...
# 12        Antwerp        NaN  NON_FLOOD_ZONE        NaN     NaN  ...
# 15          Ieper        NaN  NON_FLOOD_ZONE        NaN     1.0  ...
# 16           Mons        NaN             NaN        NaN     NaN  ...
# 19  Philippeville        NaN  NON_FLOOD_ZONE        NaN     NaN  ...
# 20       Brussels        NaN  NON_FLOOD_ZONE        0.0     1.0  ...
#
#     RoomCount ShowerCount  StateOfBuilding SubtypeOfProperty  SurfaceOfPlot  \
# 1        31.0         NaN             GOOD   apartment_block          130.0
# 2         NaN         0.0             GOOD             house            0.0
# 3         NaN         NaN    TO_BE_DONE_UP             house          170.0
# 6         NaN         0.0             GOOD             villa         2519.0
# 7         1.0         0.0              NaN             house          423.0
# 12        NaN         0.0              NaN             house         5185.0
# 15       16.0         NaN      TO_RENOVATE             house          223.0
# 16        NaN         0.0       TO_RESTORE             house          480.0
# 19        NaN         NaN      TO_RENOVATE             house          189.0
# 20        NaN         0.0             GOOD   apartment_block          178.0
#
#     SwimmingPool Terrace  ToiletCount  TypeOfProperty  \
# 1            NaN     NaN          5.0               1
# 2            NaN     NaN          2.0               1
# 3            0.0     1.0          2.0               1
# 6            NaN     1.0          5.0               1
# 7            NaN     NaN          0.0               1
# 12           NaN     NaN          3.0               1
# 15           0.0     1.0          2.0               1
# 16           NaN     NaN          2.0               1
# 19           0.0     1.0          NaN               1
# 20           NaN     NaN          3.0               1
#
#                   TypeOfSale
# 1           residential_sale
# 2           residential_sale
# 3           residential_sale
# 6   residential_monthly_rent
# 7           residential_sale
# 12          residential_sale
# 15          residential_sale
# 16          residential_sale
# 19          residential_sale
# 20          residential_sale
#
# [10 rows x 32 columns]

# %%
ofs_immoD.info()
ofs_immoD.to_csv("Sale_Dennis.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58234 entries, 1 to 118710
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         58234 non-null  int64
#  1   BathroomCount      54376 non-null  float64
#  2   BedroomCount       58234 non-null  int64
#  3   ConstructionYear   32475 non-null  float64
#  4   Country            58234 non-null  object
#  5   District           58234 non-null  object
#  6   Fireplace          3540 non-null   float64
#  7   FloodingZone       29898 non-null  object
#  8   Furnished          15599 non-null  float64
#  9   Garden             17622 non-null  float64
#  10  GardenArea         17622 non-null  float64
#  11  Kitchen            31949 non-null  object
#  12  LivingArea         49572 non-null  float64
#  13  Locality           58234 non-null  object
#  14  MonthlyCharges     2922 non-null   float64
#  15  NumberOfFacades    46684 non-null  float64
#  16  PEB                45686 non-null  object
#  17  PostalCode         58234 non-null  int64
#  18  Price              58234 non-null  int64
#  19  PropertyId         58234 non-null  int64
#  20  Province           58234 non-null  object
#  21  Region             58234 non-null  object
#  22  RoomCount          16352 non-null  float64
#  23  ShowerCount        28728 non-null  float64
#  24  StateOfBuilding    41896 non-null  object
#  25  SubtypeOfProperty  58234 non-null  object
#  26  SurfaceOfPlot      58234 non-null  float64
#  27  SwimmingPool       19596 non-null  float64
#  28  Terrace            28725 non-null  float64
#  29  ToiletCount        47775 non-null  float64
#  30  TypeOfProperty     58234 non-null  int64
#  31  TypeOfSale         58234 non-null  object
# dtypes: float64(15), int64(6), object(11)
# memory usage: 14.7+ MB

# %%
ofs_immoD=ofs_immoD[ofs_immoD.Price > 40000]
ofs_immoD.to_csv("Normal_Price.csv")

price= ofs_immoD["Price"].sort_values(ascending=0)

print(price.head(10))
# Out:
# 15881    22500000
# 11365    15000000
# 99713    15000000
# 94180    14250000
# 62774    12500000
# 72038    12500000
# 2520     11750000
# 94360    10500000
# 86919    10500000
# 47360    10500000
# Name: Price, dtype: int64

# %%
df= pd.read_csv("Normal_price.csv")
df
# Out:
#        Unnamed: 0.1  Unnamed: 0  BathroomCount  BedroomCount  \
# 0                 1           6            6.0            13
# 1                 2           8            2.0             4
# 2                 3          10            1.0             4
# 3                 7          18            0.0             2
# 4                12          27            3.0             5
# ...             ...         ...            ...           ...
# 55255        118703      181779            1.0             4
# 55256        118704      181782            3.0             7
# 55257        118707      181785            NaN             0
# 55258        118709      181788            1.0             3
# 55259        118710      181789            4.0             4
#
#        ConstructionYear  Country   District  Fireplace    FloodingZone  \
# 0                1920.0  Belgium    Tournai        NaN             NaN
# 1                2008.0  Belgium     Brugge        NaN  NON_FLOOD_ZONE
# 2                   NaN  Belgium     Veurne        NaN             NaN
# 3                   NaN  Belgium   Mechelen        NaN  NON_FLOOD_ZONE
# 4                1987.0  Belgium    Antwerp        NaN  NON_FLOOD_ZONE
# ...                 ...      ...        ...        ...             ...
# 55255            2023.0  Belgium  Diksmuide        NaN  NON_FLOOD_ZONE
# 55256               NaN  Belgium    Tournai        NaN             NaN
# 55257               NaN  Belgium   Kortrijk        NaN  NON_FLOOD_ZONE
# 55258            2024.0  Belgium       Gent        NaN             NaN
# 55259               NaN  Belgium    Antwerp        NaN             NaN
#
#        Furnished  ...  RoomCount  ShowerCount StateOfBuilding  \
# 0            0.0  ...       31.0          NaN            GOOD
# 1            1.0  ...        NaN          0.0            GOOD
# 2            NaN  ...        NaN          NaN   TO_BE_DONE_UP
# 3            NaN  ...        1.0          0.0             NaN
# 4            NaN  ...        NaN          0.0             NaN
# ...          ...  ...        ...          ...             ...
# 55255        NaN  ...        1.0          0.0            GOOD
# 55256        NaN  ...        NaN          NaN            GOOD
# 55257        NaN  ...        NaN          NaN     TO_RENOVATE
# 55258        NaN  ...        4.0          NaN            GOOD
# 55259        0.0  ...        NaN          NaN  JUST_RENOVATED
#
#        SubtypeOfProperty SurfaceOfPlot  SwimmingPool  Terrace ToiletCount  \
# 0        apartment_block         130.0           NaN      NaN         5.0
# 1                  house           0.0           NaN      NaN         2.0
# 2                  house         170.0           0.0      1.0         2.0
# 3                  house         423.0           NaN      NaN         0.0
# 4                  house        5185.0           NaN      NaN         3.0
# ...                  ...           ...           ...      ...         ...
# 55255              house         236.0           NaN      NaN         2.0
# 55256              house        6710.0           NaN      1.0         2.0
# 55257          farmhouse       10703.0           0.0      NaN         NaN
# 55258              house         234.0           NaN      NaN         0.0
# 55259    apartment_block         202.0           NaN      NaN         NaN
#
#        TypeOfProperty        TypeOfSale
# 0                   1  residential_sale
# 1                   1  residential_sale
# 2                   1  residential_sale
# 3                   1  residential_sale
# 4                   1  residential_sale
# ...               ...               ...
# 55255               1  residential_sale
# 55256               1  residential_sale
# 55257               1  residential_sale
# 55258               1  residential_sale
# 55259               1  residential_sale
#
# [55260 rows x 33 columns]

# %%
num_districts = df["District"].nunique()
print(num_districts)
Districts = df["District"].unique()
print(Districts)
# Out:
# 43
# ['Tournai' 'Brugge' 'Veurne' 'Mechelen' 'Antwerp' 'Ieper' 'Mons'
#  'Philippeville' 'Brussels' 'Soignies' 'Charleroi' 'Leuven' 'Liège'
#  'Aalst' 'Sint-Niklaas' 'Verviers' 'Marche-en-Famenne' 'Kortrijk' 'Gent'
#  'Eeklo' 'Hasselt' 'Nivelles' 'Diksmuide' 'Dendermonde' 'Huy' 'Tongeren'
#  'Dinant' 'Neufchâteau' 'Halle-Vilvoorde' 'Tielt' 'Roeselare' 'Namur'
#  'Oostend' 'Oudenaarde' 'Thuin' 'Arlon' 'Turnhout' 'Ath' 'Maaseik'
#  'Virton' 'Bastogne' 'Mouscron' 'Waremme']

# %%
pricesqm = {'Tournai':1799, 'Brugge':3670, 'Veurne':3349, 'Mechelen':2620, 'Antwerp':2614, 
        'Ieper':2188, 'Mons':1536, 'Philippeville':1549, 'Brussels':3305, 'Soignies':1812, 
        'Charleroi':1507, 'Leuven':2906, 'Liège':1969, 'Aalst':2151, 'Sint-Niklaas':2342, 
        'Verviers':1917, 'Marche-en-Famenne':1816, 'Kortrijk':2204, 'Gent':2909, 'Eeklo':2197, 
        'Hasselt':2197, 'Nivelles':2716, 'Diksmuide':2100, 'Dendermonde':2267, 'Huy':1842, 
        'Tongeren':2142, 'Dinant':1835, 'Neufchâteau':1725, 'Halle-Vilvoorde':2735, 'Tielt':2188, 
        'Roeselare':2063, 'Namur':2136, 'Oostend':2661, 'Oudenaarde':2099, 'Thuin':1540, 
        'Arlon':2375, 'Turnhout':2200, 'Ath':1834, 'Maaseik':2163, 'Virton':1917, 
        'Bastogne':1814, 'Mouscron':1799, 'Waremme':1905}

# %%
pricesqm = {'Tournai':1799, 'Brugge':3670, 'Veurne':3349, 'Mechelen':2620, 'Antwerp':2614, 
        'Ieper':2188, 'Mons':1536, 'Philippeville':1549, 'Brussels':3305, 'Soignies':1812, 
        'Charleroi':1507, 'Leuven':2906, 'Liège':1969, 'Aalst':2151, 'Sint-Niklaas':2342, 
        'Verviers':1917, 'Marche-en-Famenne':1816, 'Kortrijk':2204, 'Gent':2909, 'Eeklo':2197, 
        'Hasselt':2197, 'Nivelles':2716, 'Diksmuide':2100, 'Dendermonde':2267, 'Huy':1842, 
        'Tongeren':2142, 'Dinant':1835, 'Neufchâteau':1725, 'Halle-Vilvoorde':2735, 'Tielt':2188, 
        'Roeselare':2063, 'Namur':2136, 'Oostend':2661, 'Oudenaarde':2099, 'Thuin':1540, 
        'Arlon':2375, 'Turnhout':2200, 'Ath':1834, 'Maaseik':2163, 'Virton':1917, 
        'Bastogne':1814, 'Mouscron':1799, 'Waremme':1905}

df['pricesqm'] = df['District'].map(pricesqm)
df.to_csv("dfpsqm.csv")
print(df.head(10))
# Out:
#    Unnamed: 0.1  Unnamed: 0  BathroomCount  BedroomCount  ConstructionYear  \
# 0             1           6            6.0            13            1920.0
# 1             2           8            2.0             4            2008.0
# 2             3          10            1.0             4               NaN
# 3             7          18            0.0             2               NaN
# 4            12          27            3.0             5            1987.0
# 5            15          33            1.0             8            1923.0
# 6            16          34            1.0             3               NaN
# 7            19          37            0.0             1            1860.0
# 8            20          38            2.0             0            1950.0
# 9            21          39            9.0            14               NaN
#
#    Country       District  Fireplace    FloodingZone  Furnished  ...  \
# 0  Belgium        Tournai        NaN             NaN        0.0  ...
# 1  Belgium         Brugge        NaN  NON_FLOOD_ZONE        1.0  ...
# 2  Belgium         Veurne        NaN             NaN        NaN  ...
# 3  Belgium       Mechelen        NaN  NON_FLOOD_ZONE        NaN  ...
# 4  Belgium        Antwerp        NaN  NON_FLOOD_ZONE        NaN  ...
# 5  Belgium          Ieper        NaN  NON_FLOOD_ZONE        NaN  ...
# 6  Belgium           Mons        NaN             NaN        NaN  ...
# 7  Belgium  Philippeville        NaN  NON_FLOOD_ZONE        NaN  ...
# 8  Belgium       Brussels        NaN  NON_FLOOD_ZONE        0.0  ...
# 9  Belgium       Soignies        NaN             NaN        0.0  ...
#
#    ShowerCount  StateOfBuilding SubtypeOfProperty  SurfaceOfPlot SwimmingPool  \
# 0          NaN             GOOD   apartment_block          130.0          NaN
# 1          0.0             GOOD             house            0.0          NaN
# 2          NaN    TO_BE_DONE_UP             house          170.0          0.0
# 3          0.0              NaN             house          423.0          NaN
# 4          0.0              NaN             house         5185.0          NaN
# 5          NaN      TO_RENOVATE             house          223.0          0.0
# 6          0.0       TO_RESTORE             house          480.0          NaN
# 7          NaN      TO_RENOVATE             house          189.0          0.0
# 8          0.0             GOOD   apartment_block          178.0          NaN
# 9          NaN             GOOD   apartment_block          405.0          NaN
#
#    Terrace  ToiletCount TypeOfProperty        TypeOfSale  pricesqm
# 0      NaN          5.0              1  residential_sale      1799
# 1      NaN          2.0              1  residential_sale      3670
# 2      1.0          2.0              1  residential_sale      3349
# 3      NaN          0.0              1  residential_sale      2620
# 4      NaN          3.0              1  residential_sale      2614
# 5      1.0          2.0              1  residential_sale      2188
# 6      NaN          2.0              1  residential_sale      1536
# 7      1.0          NaN              1  residential_sale      1549
# 8      NaN          3.0              1  residential_sale      3305
# 9      NaN          NaN              1  residential_sale      1812
#
# [10 rows x 34 columns]

# %%
df_prices=pd.read_csv("dfpsqm.csv")
df_prices
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  BathroomCount  BedroomCount  \
# 0                 0             1           6            6.0            13
# 1                 1             2           8            2.0             4
# 2                 2             3          10            1.0             4
# 3                 3             7          18            0.0             2
# 4                 4            12          27            3.0             5
# ...             ...           ...         ...            ...           ...
# 55255         55255        118703      181779            1.0             4
# 55256         55256        118704      181782            3.0             7
# 55257         55257        118707      181785            NaN             0
# 55258         55258        118709      181788            1.0             3
# 55259         55259        118710      181789            4.0             4
#
#        ConstructionYear  Country   District  Fireplace    FloodingZone  ...  \
# 0                1920.0  Belgium    Tournai        NaN             NaN  ...
# 1                2008.0  Belgium     Brugge        NaN  NON_FLOOD_ZONE  ...
# 2                   NaN  Belgium     Veurne        NaN             NaN  ...
# 3                   NaN  Belgium   Mechelen        NaN  NON_FLOOD_ZONE  ...
# 4                1987.0  Belgium    Antwerp        NaN  NON_FLOOD_ZONE  ...
# ...                 ...      ...        ...        ...             ...  ...
# 55255            2023.0  Belgium  Diksmuide        NaN  NON_FLOOD_ZONE  ...
# 55256               NaN  Belgium    Tournai        NaN             NaN  ...
# 55257               NaN  Belgium   Kortrijk        NaN  NON_FLOOD_ZONE  ...
# 55258            2024.0  Belgium       Gent        NaN             NaN  ...
# 55259               NaN  Belgium    Antwerp        NaN             NaN  ...
#
#        ShowerCount  StateOfBuilding  SubtypeOfProperty SurfaceOfPlot  \
# 0              NaN             GOOD    apartment_block         130.0
# 1              0.0             GOOD              house           0.0
# 2              NaN    TO_BE_DONE_UP              house         170.0
# 3              0.0              NaN              house         423.0
# 4              0.0              NaN              house        5185.0
# ...            ...              ...                ...           ...
# 55255          0.0             GOOD              house         236.0
# 55256          NaN             GOOD              house        6710.0
# 55257          NaN      TO_RENOVATE          farmhouse       10703.0
# 55258          NaN             GOOD              house         234.0
# 55259          NaN   JUST_RENOVATED    apartment_block         202.0
#
#        SwimmingPool Terrace  ToiletCount  TypeOfProperty        TypeOfSale  \
# 0               NaN     NaN          5.0               1  residential_sale
# 1               NaN     NaN          2.0               1  residential_sale
# 2               0.0     1.0          2.0               1  residential_sale
# 3               NaN     NaN          0.0               1  residential_sale
# 4               NaN     NaN          3.0               1  residential_sale
# ...             ...     ...          ...             ...               ...
# 55255           NaN     NaN          2.0               1  residential_sale
# 55256           NaN     1.0          2.0               1  residential_sale
# 55257           0.0     NaN          NaN               1  residential_sale
# 55258           NaN     NaN          0.0               1  residential_sale
# 55259           NaN     NaN          NaN               1  residential_sale
#
#        pricesqm
# 0          1799
# 1          3670
# 2          3349
# 3          2620
# 4          2614
# ...         ...
# 55255      2100
# 55256      1799
# 55257      2204
# 55258      2909
# 55259      2614
#
# [55260 rows x 35 columns]

# %%
df_prices = df_prices.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.2'])
df_prices
# Out:
#        BathroomCount  BedroomCount  ConstructionYear  Country   District  \
# 0                6.0            13            1920.0  Belgium    Tournai
# 1                2.0             4            2008.0  Belgium     Brugge
# 2                1.0             4               NaN  Belgium     Veurne
# 3                0.0             2               NaN  Belgium   Mechelen
# 4                3.0             5            1987.0  Belgium    Antwerp
# ...              ...           ...               ...      ...        ...
# 55255            1.0             4            2023.0  Belgium  Diksmuide
# 55256            3.0             7               NaN  Belgium    Tournai
# 55257            NaN             0               NaN  Belgium   Kortrijk
# 55258            1.0             3            2024.0  Belgium       Gent
# 55259            4.0             4               NaN  Belgium    Antwerp
#
#        Fireplace    FloodingZone  Furnished  Garden  GardenArea  ...  \
# 0            NaN             NaN        0.0     NaN         NaN  ...
# 1            NaN  NON_FLOOD_ZONE        1.0     NaN         NaN  ...
# 2            NaN             NaN        NaN     1.0         1.0  ...
# 3            NaN  NON_FLOOD_ZONE        NaN     NaN         NaN  ...
# 4            NaN  NON_FLOOD_ZONE        NaN     NaN         NaN  ...
# ...          ...             ...        ...     ...         ...  ...
# 55255        NaN  NON_FLOOD_ZONE        NaN     NaN         NaN  ...
# 55256        NaN             NaN        NaN     NaN         NaN  ...
# 55257        NaN  NON_FLOOD_ZONE        NaN     1.0         1.0  ...
# 55258        NaN             NaN        NaN     1.0       168.0  ...
# 55259        NaN             NaN        0.0     NaN         NaN  ...
#
#       ShowerCount  StateOfBuilding SubtypeOfProperty  SurfaceOfPlot  \
# 0             NaN             GOOD   apartment_block          130.0
# 1             0.0             GOOD             house            0.0
# 2             NaN    TO_BE_DONE_UP             house          170.0
# 3             0.0              NaN             house          423.0
# 4             0.0              NaN             house         5185.0
# ...           ...              ...               ...            ...
# 55255         0.0             GOOD             house          236.0
# 55256         NaN             GOOD             house         6710.0
# 55257         NaN      TO_RENOVATE         farmhouse        10703.0
# 55258         NaN             GOOD             house          234.0
# 55259         NaN   JUST_RENOVATED   apartment_block          202.0
#
#        SwimmingPool Terrace  ToiletCount  TypeOfProperty        TypeOfSale  \
# 0               NaN     NaN          5.0               1  residential_sale
# 1               NaN     NaN          2.0               1  residential_sale
# 2               0.0     1.0          2.0               1  residential_sale
# 3               NaN     NaN          0.0               1  residential_sale
# 4               NaN     NaN          3.0               1  residential_sale
# ...             ...     ...          ...             ...               ...
# 55255           NaN     NaN          2.0               1  residential_sale
# 55256           NaN     1.0          2.0               1  residential_sale
# 55257           0.0     NaN          NaN               1  residential_sale
# 55258           NaN     NaN          0.0               1  residential_sale
# 55259           NaN     NaN          NaN               1  residential_sale
#
#       pricesqm
# 0         1799
# 1         3670
# 2         3349
# 3         2620
# 4         2614
# ...        ...
# 55255     2100
# 55256     1799
# 55257     2204
# 55258     2909
# 55259     2614
#
# [55260 rows x 32 columns]

# %%
df_prices = df_prices.select_dtypes(include=['float64', 'int'])
corr_matrix = df_prices.corr(method='pearson')
corr_matrix
# Out:
#                   BathroomCount  BedroomCount  ConstructionYear  Fireplace  \
# BathroomCount          1.000000      0.518067         -0.061813        NaN
# BedroomCount           0.518067      1.000000         -0.037771        NaN
# ConstructionYear      -0.061813     -0.037771          1.000000        NaN
# Fireplace                   NaN           NaN               NaN        NaN
# Furnished              0.147874      0.081733         -0.033007        NaN
# Garden                      NaN           NaN               NaN        NaN
# GardenArea             0.010133      0.001586         -0.055632        NaN
# LivingArea             0.313337      0.274493         -0.055247        NaN
# MonthlyCharges         0.541351      0.324628         -0.030783        NaN
# NumberOfFacades        0.041814      0.073980          0.120691        NaN
# PostalCode            -0.155860     -0.083477          0.101396        NaN
# Price                  0.456386      0.322546          0.027943        NaN
# PropertyId            -0.011961     -0.013598         -0.021431        NaN
# RoomCount              0.242366      0.238522         -0.015069        NaN
# ShowerCount            0.060538      0.047929         -0.037410        NaN
# SurfaceOfPlot          0.003950      0.002543         -0.000469        NaN
# SwimmingPool           0.200379      0.132397          0.073930        NaN
# Terrace                     NaN           NaN               NaN        NaN
# ToiletCount            0.002870      0.003598         -0.001692        NaN
# TypeOfProperty              NaN           NaN               NaN        NaN
# pricesqm               0.114124      0.061084          0.002265        NaN
#
#                   Furnished  Garden  GardenArea  LivingArea  MonthlyCharges  \
# BathroomCount      0.147874     NaN    0.010133    0.313337        0.541351
# BedroomCount       0.081733     NaN    0.001586    0.274493        0.324628
# ConstructionYear  -0.033007     NaN   -0.055632   -0.055247       -0.030783
# Fireplace               NaN     NaN         NaN         NaN             NaN
# Furnished          1.000000     NaN    0.075367    0.034908             NaN
# Garden                  NaN     NaN         NaN         NaN             NaN
# GardenArea         0.075367     NaN    1.000000    0.005411        0.070290
# LivingArea         0.034908     NaN    0.005411    1.000000        0.543806
# MonthlyCharges          NaN     NaN    0.070290    0.543806        1.000000
# NumberOfFacades    0.047782     NaN    0.009394    0.092473        0.217330
# PostalCode         0.036525     NaN    0.005772   -0.045192        0.072180
# Price              0.074277     NaN    0.005661    0.302757        0.142338
# PropertyId         0.016327     NaN   -0.003160   -0.017409       -0.051009
# RoomCount         -0.180860     NaN    0.071660    0.094069        0.508803
# ShowerCount        0.007740     NaN    0.023361    0.020355        0.134224
# SurfaceOfPlot     -0.001422     NaN    0.000011    0.005910        0.292859
# SwimmingPool       0.043891     NaN   -0.003025    0.154412             NaN
# Terrace                 NaN     NaN         NaN         NaN             NaN
# ToiletCount       -0.002140     NaN    0.000393    0.007091        0.554611
# TypeOfProperty          NaN     NaN         NaN         NaN             NaN
# pricesqm          -0.013648     NaN   -0.007894    0.024776        0.062400
#
#                   NumberOfFacades  ...     Price  PropertyId  RoomCount  \
# BathroomCount            0.041814  ...  0.456386   -0.011961   0.242366
# BedroomCount             0.073980  ...  0.322546   -0.013598   0.238522
# ConstructionYear         0.120691  ...  0.027943   -0.021431  -0.015069
# Fireplace                     NaN  ...       NaN         NaN        NaN
# Furnished                0.047782  ...  0.074277    0.016327  -0.180860
# Garden                        NaN  ...       NaN         NaN        NaN
# GardenArea               0.009394  ...  0.005661   -0.003160   0.071660
# LivingArea               0.092473  ...  0.302757   -0.017409   0.094069
# MonthlyCharges           0.217330  ...  0.142338   -0.051009   0.508803
# NumberOfFacades          1.000000  ...  0.194161    0.006324  -0.061624
# PostalCode               0.009419  ... -0.119987   -0.029728  -0.047745
# Price                    0.194161  ...  1.000000   -0.014542   0.095218
# PropertyId               0.006324  ... -0.014542    1.000000  -0.004159
# RoomCount               -0.061624  ...  0.095218   -0.004159   1.000000
# ShowerCount             -0.011513  ...  0.025050   -0.009056   0.534005
# SurfaceOfPlot            0.007394  ...  0.011199   -0.001481   0.021687
# SwimmingPool             0.287511  ...  0.347351    0.011328  -0.116405
# Terrace                       NaN  ...       NaN         NaN        NaN
# ToiletCount             -0.000169  ...  0.000590   -0.002079   0.275424
# TypeOfProperty                NaN  ...       NaN         NaN        NaN
# pricesqm                -0.016540  ...  0.331371    0.031085  -0.086360
#
#                   ShowerCount  SurfaceOfPlot  SwimmingPool  Terrace  \
# BathroomCount        0.060538       0.003950      0.200379      NaN
# BedroomCount         0.047929       0.002543      0.132397      NaN
# ConstructionYear    -0.037410      -0.000469      0.073930      NaN
# Fireplace                 NaN            NaN           NaN      NaN
# Furnished            0.007740      -0.001422      0.043891      NaN
# Garden                    NaN            NaN           NaN      NaN
# GardenArea           0.023361       0.000011     -0.003025      NaN
# LivingArea           0.020355       0.005910      0.154412      NaN
# MonthlyCharges       0.134224       0.292859           NaN      NaN
# NumberOfFacades     -0.011513       0.007394      0.287511      NaN
# PostalCode          -0.016158      -0.006246     -0.066474      NaN
# Price                0.025050       0.011199      0.347351      NaN
# PropertyId          -0.009056      -0.001481      0.011328      NaN
# RoomCount            0.534005       0.021687     -0.116405      NaN
# ShowerCount          1.000000       0.000845     -0.007806      NaN
# SurfaceOfPlot        0.000845       1.000000      0.024976      NaN
# SwimmingPool        -0.007806       0.024976      1.000000      NaN
# Terrace                   NaN            NaN           NaN      NaN
# ToiletCount          0.008134      -0.000019     -0.002812      NaN
# TypeOfProperty            NaN            NaN           NaN      NaN
# pricesqm            -0.009680       0.002513      0.048133      NaN
#
#                   ToiletCount  TypeOfProperty  pricesqm
# BathroomCount        0.002870             NaN  0.114124
# BedroomCount         0.003598             NaN  0.061084
# ConstructionYear    -0.001692             NaN  0.002265
# Fireplace                 NaN             NaN       NaN
# Furnished           -0.002140             NaN -0.013648
# Garden                    NaN             NaN       NaN
# GardenArea           0.000393             NaN -0.007894
# LivingArea           0.007091             NaN  0.024776
# MonthlyCharges       0.554611             NaN  0.062400
# NumberOfFacades     -0.000169             NaN -0.016540
# PostalCode          -0.002790             NaN -0.231643
# Price                0.000590             NaN  0.331371
# PropertyId          -0.002079             NaN  0.031085
# RoomCount            0.275424             NaN -0.086360
# ShowerCount          0.008134             NaN -0.009680
# SurfaceOfPlot       -0.000019             NaN  0.002513
# SwimmingPool        -0.002812             NaN  0.048133
# Terrace                   NaN             NaN       NaN
# ToiletCount          1.000000             NaN -0.001533
# TypeOfProperty            NaN             NaN       NaN
# pricesqm            -0.001533             NaN  1.000000
#
# [21 rows x 21 columns]

# %%
sns.heatmap(corr_matrix, annot=False, cmap = "coolwarm", vmax=1, vmin =-1)
plt.title("correlations")
plt.show()

# %%
ofs_immoD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55260 entries, 1 to 118710
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         55260 non-null  int64
#  1   BathroomCount      51581 non-null  float64
#  2   BedroomCount       55260 non-null  int64
#  3   ConstructionYear   31200 non-null  float64
#  4   Country            55260 non-null  object
#  5   District           55260 non-null  object
#  6   Fireplace          3261 non-null   float64
#  7   FloodingZone       28755 non-null  object
#  8   Furnished          15571 non-null  float64
#  9   Garden             16452 non-null  float64
#  10  GardenArea         16452 non-null  float64
#  11  Kitchen            29938 non-null  object
#  12  LivingArea         47269 non-null  float64
#  13  Locality           55260 non-null  object
#  14  MonthlyCharges     87 non-null     float64
#  15  NumberOfFacades    44173 non-null  float64
#  16  PEB                43280 non-null  object
#  17  PostalCode         55260 non-null  int64
#  18  Price              55260 non-null  int64
#  19  PropertyId         55260 non-null  int64
#  20  Province           55260 non-null  object
#  21  Region             55260 non-null  object
#  22  RoomCount          15560 non-null  float64
#  23  ShowerCount        27090 non-null  float64
#  24  StateOfBuilding    39678 non-null  object
#  25  SubtypeOfProperty  55260 non-null  object
#  26  SurfaceOfPlot      55260 non-null  float64
#  27  SwimmingPool       18175 non-null  float64
#  28  Terrace            26915 non-null  float64
#  29  ToiletCount        45194 non-null  float64
#  30  TypeOfProperty     55260 non-null  int64
#  31  TypeOfSale         55260 non-null  object
# dtypes: float64(15), int64(6), object(11)
# memory usage: 13.9+ MB

# %%
correlation = ofs_immoD['Price'].corr(ofs_immoD['PostalCode'])
print(correlation)
# Out:
# -0.11998710270519407

# %%
fig, ax = plt.subplots(1, 1, figsize=(6,4))
ax.scatter(x=ofs_immoD.Price, y=ofs_immoD.PostalCode, alpha= 0.3)
ax.set_xlabel('Price')
ax.set_ylabel('PostalCode')
# Out:
# Text(0, 0.5, 'PostalCode')

# %%
price= ofs_immoD["Price"].sort_values()

print(price.head(10))
# Out:
# 102207    42000
# 56538     43000
# 24261     43000
# 28407     44438
# 91209     44500
# 47383     44900
# 89125     44999
# 88736     45000
# 5070      45000
# 42033     45000
# Name: Price, dtype: int64

# %%
ofs_immoD = ofs_immoD.select_dtypes(include=['float64', 'int'])
corr_matrixs= ofs_immoD.corr(method='spearman')
corr_matrixs
# Out:
#                   Unnamed: 0  BathroomCount  BedroomCount  ConstructionYear  \
# Unnamed: 0          1.000000      -0.003904     -0.000250          0.043352
# BathroomCount      -0.003904       1.000000      0.435197         -0.078272
# BedroomCount       -0.000250       0.435197      1.000000         -0.037700
# ConstructionYear    0.043352      -0.078272     -0.037700          1.000000
# Fireplace                NaN            NaN           NaN               NaN
# Furnished          -0.016981       0.066031      0.033055         -0.029396
# Garden                   NaN            NaN           NaN               NaN
# GardenArea         -0.002737       0.127135      0.165275         -0.015484
# LivingArea         -0.009885       0.424901      0.574217         -0.045425
# MonthlyCharges     -0.043808       0.266646      0.250840          0.140276
# NumberOfFacades    -0.014013       0.064357      0.128393          0.173754
# PostalCode          0.016851      -0.195549     -0.120404          0.148678
# Price              -0.031655       0.383453      0.419292          0.196997
# PropertyId         -0.592060       0.013320      0.003691         -0.099280
# RoomCount          -0.007554       0.234634      0.177137         -0.015094
# ShowerCount         0.017828       0.189051      0.184518         -0.071946
# SurfaceOfPlot      -0.010674       0.135861      0.225605          0.029981
# SwimmingPool       -0.014721       0.250838      0.221387          0.072808
# Terrace                  NaN            NaN           NaN               NaN
# ToiletCount        -0.005979       0.495643      0.354154          0.044864
# TypeOfProperty           NaN            NaN           NaN               NaN
#
#                   Fireplace  Furnished  Garden  GardenArea  LivingArea  \
# Unnamed: 0              NaN  -0.016981     NaN   -0.002737   -0.009885
# BathroomCount           NaN   0.066031     NaN    0.127135    0.424901
# BedroomCount            NaN   0.033055     NaN    0.165275    0.574217
# ConstructionYear        NaN  -0.029396     NaN   -0.015484   -0.045425
# Fireplace               NaN        NaN     NaN         NaN         NaN
# Furnished               NaN   1.000000     NaN    0.004755    0.004698
# Garden                  NaN        NaN     NaN         NaN         NaN
# GardenArea              NaN   0.004755     NaN    1.000000    0.258967
# LivingArea              NaN   0.004698     NaN    0.258967    1.000000
# MonthlyCharges          NaN        NaN     NaN    0.036767    0.488590
# NumberOfFacades         NaN   0.049074     NaN    0.502084    0.226490
# PostalCode              NaN   0.035656     NaN    0.002099   -0.120367
# Price                   NaN   0.037662     NaN    0.211849    0.629983
# PropertyId              NaN   0.021574     NaN   -0.009207    0.004095
# RoomCount               NaN  -0.219538     NaN    0.114327    0.158239
# ShowerCount             NaN   0.020821     NaN    0.069359    0.110101
# SurfaceOfPlot           NaN  -0.001562     NaN    0.682971    0.368719
# SwimmingPool            NaN   0.043891     NaN    0.244335    0.298363
# Terrace                 NaN        NaN     NaN         NaN         NaN
# ToiletCount             NaN   0.058683     NaN    0.093786    0.381875
# TypeOfProperty          NaN        NaN     NaN         NaN         NaN
#
#                   MonthlyCharges  ...  PostalCode     Price  PropertyId  \
# Unnamed: 0             -0.043808  ...    0.016851 -0.031655   -0.592060
# BathroomCount           0.266646  ...   -0.195549  0.383453    0.013320
# BedroomCount            0.250840  ...   -0.120404  0.419292    0.003691
# ConstructionYear        0.140276  ...    0.148678  0.196997   -0.099280
# Fireplace                    NaN  ...         NaN       NaN         NaN
# Furnished                    NaN  ...    0.035656  0.037662    0.021574
# Garden                       NaN  ...         NaN       NaN         NaN
# GardenArea              0.036767  ...    0.002099  0.211849   -0.009207
# LivingArea              0.488590  ...   -0.120367  0.629983    0.004095
# MonthlyCharges          1.000000  ...    0.055755  0.240017   -0.021485
# NumberOfFacades         0.385962  ...    0.018009  0.299623    0.019375
# PostalCode              0.055755  ...    1.000000 -0.196978   -0.037795
# Price                   0.240017  ...   -0.196978  1.000000    0.011053
# PropertyId             -0.021485  ...   -0.037795  0.011053    1.000000
# RoomCount               0.398803  ...   -0.001875  0.140765   -0.009319
# ShowerCount             0.050126  ...   -0.147207  0.051552   -0.003270
# SurfaceOfPlot           0.341333  ...   -0.014113  0.364844    0.024849
# SwimmingPool                 NaN  ...   -0.062299  0.331618   -0.001241
# Terrace                      NaN  ...         NaN       NaN         NaN
# ToiletCount             0.300316  ...   -0.166457  0.365074   -0.007461
# TypeOfProperty               NaN  ...         NaN       NaN         NaN
#
#                   RoomCount  ShowerCount  SurfaceOfPlot  SwimmingPool  \
# Unnamed: 0        -0.007554     0.017828      -0.010674     -0.014721
# BathroomCount      0.234634     0.189051       0.135861      0.250838
# BedroomCount       0.177137     0.184518       0.225605      0.221387
# ConstructionYear  -0.015094    -0.071946       0.029981      0.072808
# Fireplace               NaN          NaN            NaN           NaN
# Furnished         -0.219538     0.020821      -0.001562      0.043891
# Garden                  NaN          NaN            NaN           NaN
# GardenArea         0.114327     0.069359       0.682971      0.244335
# LivingArea         0.158239     0.110101       0.368719      0.298363
# MonthlyCharges     0.398803     0.050126       0.341333           NaN
# NumberOfFacades   -0.128317    -0.060342       0.643889      0.298552
# PostalCode        -0.001875    -0.147207      -0.014113     -0.062299
# Price              0.140765     0.051552       0.364844      0.331618
# PropertyId        -0.009319    -0.003270       0.024849     -0.001241
# RoomCount          1.000000     0.670103       0.113271     -0.178578
# ShowerCount        0.670103     1.000000       0.014752     -0.092071
# SurfaceOfPlot      0.113271     0.014752       1.000000      0.329355
# SwimmingPool      -0.178578    -0.092071       0.329355      1.000000
# Terrace                 NaN          NaN            NaN           NaN
# ToiletCount        0.233273     0.329326       0.094349      0.185545
# TypeOfProperty          NaN          NaN            NaN           NaN
#
#                   Terrace  ToiletCount  TypeOfProperty
# Unnamed: 0            NaN    -0.005979             NaN
# BathroomCount         NaN     0.495643             NaN
# BedroomCount          NaN     0.354154             NaN
# ConstructionYear      NaN     0.044864             NaN
# Fireplace             NaN          NaN             NaN
# Furnished             NaN     0.058683             NaN
# Garden                NaN          NaN             NaN
# GardenArea            NaN     0.093786             NaN
# LivingArea            NaN     0.381875             NaN
# MonthlyCharges        NaN     0.300316             NaN
# NumberOfFacades       NaN     0.013237             NaN
# PostalCode            NaN    -0.166457             NaN
# Price                 NaN     0.365074             NaN
# PropertyId            NaN    -0.007461             NaN
# RoomCount             NaN     0.233273             NaN
# ShowerCount           NaN     0.329326             NaN
# SurfaceOfPlot         NaN     0.094349             NaN
# SwimmingPool          NaN     0.185545             NaN
# Terrace               NaN          NaN             NaN
# ToiletCount           NaN     1.000000             NaN
# TypeOfProperty        NaN          NaN             NaN
#
# [21 rows x 21 columns]

# %%
ofs_immoD = ofs_immoD.select_dtypes(include=['float64', 'int'])
corr_matrix = ofs_immoD.corr(method='pearson')
corr_matrix
# Out:
#                   Unnamed: 0  BathroomCount  BedroomCount  ConstructionYear  \
# Unnamed: 0          1.000000       0.015113      0.012886          0.034472
# BathroomCount       0.015113       1.000000      0.518067         -0.061813
# BedroomCount        0.012886       0.518067      1.000000         -0.037771
# ConstructionYear    0.034472      -0.061813     -0.037771          1.000000
# Fireplace                NaN            NaN           NaN               NaN
# Furnished          -0.020319       0.147874      0.081733         -0.033007
# Garden                   NaN            NaN           NaN               NaN
# GardenArea          0.005827       0.010133      0.001586         -0.055632
# LivingArea         -0.009323       0.313337      0.274493         -0.055247
# MonthlyCharges     -0.063402       0.541351      0.324628         -0.030783
# NumberOfFacades    -0.016776       0.041814      0.073980          0.120691
# PostalCode          0.020190      -0.155860     -0.083477          0.101396
# Price               0.003483       0.456386      0.322546          0.027943
# PropertyId         -0.424658      -0.011961     -0.013598         -0.021431
# RoomCount          -0.009491       0.242366      0.238522         -0.015069
# ShowerCount         0.005775       0.060538      0.047929         -0.037410
# SurfaceOfPlot      -0.004492       0.003950      0.002543         -0.000469
# SwimmingPool       -0.012482       0.200379      0.132397          0.073930
# Terrace                  NaN            NaN           NaN               NaN
# ToiletCount         0.007686       0.002870      0.003598         -0.001692
# TypeOfProperty           NaN            NaN           NaN               NaN
#
#                   Fireplace  Furnished  Garden  GardenArea  LivingArea  \
# Unnamed: 0              NaN  -0.020319     NaN    0.005827   -0.009323
# BathroomCount           NaN   0.147874     NaN    0.010133    0.313337
# BedroomCount            NaN   0.081733     NaN    0.001586    0.274493
# ConstructionYear        NaN  -0.033007     NaN   -0.055632   -0.055247
# Fireplace               NaN        NaN     NaN         NaN         NaN
# Furnished               NaN   1.000000     NaN    0.075367    0.034908
# Garden                  NaN        NaN     NaN         NaN         NaN
# GardenArea              NaN   0.075367     NaN    1.000000    0.005411
# LivingArea              NaN   0.034908     NaN    0.005411    1.000000
# MonthlyCharges          NaN        NaN     NaN    0.070290    0.543806
# NumberOfFacades         NaN   0.047782     NaN    0.009394    0.092473
# PostalCode              NaN   0.036525     NaN    0.005772   -0.045192
# Price                   NaN   0.074277     NaN    0.005661    0.302757
# PropertyId              NaN   0.016327     NaN   -0.003160   -0.017409
# RoomCount               NaN  -0.180860     NaN    0.071660    0.094069
# ShowerCount             NaN   0.007740     NaN    0.023361    0.020355
# SurfaceOfPlot           NaN  -0.001422     NaN    0.000011    0.005910
# SwimmingPool            NaN   0.043891     NaN   -0.003025    0.154412
# Terrace                 NaN        NaN     NaN         NaN         NaN
# ToiletCount             NaN  -0.002140     NaN    0.000393    0.007091
# TypeOfProperty          NaN        NaN     NaN         NaN         NaN
#
#                   MonthlyCharges  ...  PostalCode     Price  PropertyId  \
# Unnamed: 0             -0.063402  ...    0.020190  0.003483   -0.424658
# BathroomCount           0.541351  ...   -0.155860  0.456386   -0.011961
# BedroomCount            0.324628  ...   -0.083477  0.322546   -0.013598
# ConstructionYear       -0.030783  ...    0.101396  0.027943   -0.021431
# Fireplace                    NaN  ...         NaN       NaN         NaN
# Furnished                    NaN  ...    0.036525  0.074277    0.016327
# Garden                       NaN  ...         NaN       NaN         NaN
# GardenArea              0.070290  ...    0.005772  0.005661   -0.003160
# LivingArea              0.543806  ...   -0.045192  0.302757   -0.017409
# MonthlyCharges          1.000000  ...    0.072180  0.142338   -0.051009
# NumberOfFacades         0.217330  ...    0.009419  0.194161    0.006324
# PostalCode              0.072180  ...    1.000000 -0.119987   -0.029728
# Price                   0.142338  ...   -0.119987  1.000000   -0.014542
# PropertyId             -0.051009  ...   -0.029728 -0.014542    1.000000
# RoomCount               0.508803  ...   -0.047745  0.095218   -0.004159
# ShowerCount             0.134224  ...   -0.016158  0.025050   -0.009056
# SurfaceOfPlot           0.292859  ...   -0.006246  0.011199   -0.001481
# SwimmingPool                 NaN  ...   -0.066474  0.347351    0.011328
# Terrace                      NaN  ...         NaN       NaN         NaN
# ToiletCount             0.554611  ...   -0.002790  0.000590   -0.002079
# TypeOfProperty               NaN  ...         NaN       NaN         NaN
#
#                   RoomCount  ShowerCount  SurfaceOfPlot  SwimmingPool  \
# Unnamed: 0        -0.009491     0.005775      -0.004492     -0.012482
# BathroomCount      0.242366     0.060538       0.003950      0.200379
# BedroomCount       0.238522     0.047929       0.002543      0.132397
# ConstructionYear  -0.015069    -0.037410      -0.000469      0.073930
# Fireplace               NaN          NaN            NaN           NaN
# Furnished         -0.180860     0.007740      -0.001422      0.043891
# Garden                  NaN          NaN            NaN           NaN
# GardenArea         0.071660     0.023361       0.000011     -0.003025
# LivingArea         0.094069     0.020355       0.005910      0.154412
# MonthlyCharges     0.508803     0.134224       0.292859           NaN
# NumberOfFacades   -0.061624    -0.011513       0.007394      0.287511
# PostalCode        -0.047745    -0.016158      -0.006246     -0.066474
# Price              0.095218     0.025050       0.011199      0.347351
# PropertyId        -0.004159    -0.009056      -0.001481      0.011328
# RoomCount          1.000000     0.534005       0.021687     -0.116405
# ShowerCount        0.534005     1.000000       0.000845     -0.007806
# SurfaceOfPlot      0.021687     0.000845       1.000000      0.024976
# SwimmingPool      -0.116405    -0.007806       0.024976      1.000000
# Terrace                 NaN          NaN            NaN           NaN
# ToiletCount        0.275424     0.008134      -0.000019     -0.002812
# TypeOfProperty          NaN          NaN            NaN           NaN
#
#                   Terrace  ToiletCount  TypeOfProperty
# Unnamed: 0            NaN     0.007686             NaN
# BathroomCount         NaN     0.002870             NaN
# BedroomCount          NaN     0.003598             NaN
# ConstructionYear      NaN    -0.001692             NaN
# Fireplace             NaN          NaN             NaN
# Furnished             NaN    -0.002140             NaN
# Garden                NaN          NaN             NaN
# GardenArea            NaN     0.000393             NaN
# LivingArea            NaN     0.007091             NaN
# MonthlyCharges        NaN     0.554611             NaN
# NumberOfFacades       NaN    -0.000169             NaN
# PostalCode            NaN    -0.002790             NaN
# Price                 NaN     0.000590             NaN
# PropertyId            NaN    -0.002079             NaN
# RoomCount             NaN     0.275424             NaN
# ShowerCount           NaN     0.008134             NaN
# SurfaceOfPlot         NaN    -0.000019             NaN
# SwimmingPool          NaN    -0.002812             NaN
# Terrace               NaN          NaN             NaN
# ToiletCount           NaN     1.000000             NaN
# TypeOfProperty        NaN          NaN             NaN
#
# [21 rows x 21 columns]

# %%
r, p = stats.pearsonr(ofs_immoD['Price'], ofs_immoD['PostalCode'])
print(f"Correlación Pearson: r={r}, p-value={p}")
# Out:
# Correlación Pearson: r=-0.119987102705194, p-value=2.7877179161176017e-176

# %%
sns.heatmap(corr_matrix, annot=False, cmap = "coolwarm", vmax=1, vmin =-1)
plt.title("correlations")
plt.show()

# %%
print(ofs_immoD.mean())
# Out:
# Unnamed: 0          8.074141e+04
# BathroomCount       1.363971e+00
# BedroomCount        3.503040e+00
# ConstructionYear    1.971679e+03
# Fireplace           1.000000e+00
# Furnished           4.360670e-02
# Garden              1.000000e+00
# GardenArea          6.158174e+04
# LivingArea          2.237060e+02
# MonthlyCharges      9.503563e+02
# NumberOfFacades     3.012496e+00
# PostalCode          5.581704e+03
# Price               4.820966e+05
# PropertyId          1.246079e+07
# RoomCount           8.242224e+00
# ShowerCount         8.054264e-01
# SurfaceOfPlot       3.250658e+03
# SwimmingPool        8.874828e-02
# Terrace             1.000000e+00
# ToiletCount         8.663739e+01
# TypeOfProperty      1.000000e+00
# dtype: float64

# %%
print(ofs_immoD.std())
# Out:
# Unnamed: 0          4.236010e+04
# BathroomCount       1.148062e+00
# BedroomCount        2.074110e+00
# ConstructionYear    5.702791e+01
# Fireplace           0.000000e+00
# Furnished           2.042250e-01
# Garden              0.000000e+00
# GardenArea          7.796335e+06
# LivingArea          3.145387e+02
# MonthlyCharges      7.386539e+02
# NumberOfFacades     8.588079e-01
# PostalCode          2.934370e+03
# Price               5.316041e+05
# PropertyId          3.074943e+06
# RoomCount           6.391827e+00
# ShowerCount         8.684105e+00
# SurfaceOfPlot       4.903348e+05
# SwimmingPool        2.843879e-01
# Terrace             0.000000e+00
# ToiletCount         1.802712e+04
# TypeOfProperty      1.110233e-16
# dtype: float64

# %%
Distritos = ofs_immoD["District"].unique()
print(Districts)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\admin\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'District'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 Distritos = ofs_immoD["District"].unique()
#       2 print(Districts)
#
# File c:\Users\admin\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\admin\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'District'
